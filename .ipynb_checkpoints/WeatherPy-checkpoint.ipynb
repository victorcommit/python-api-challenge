# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
     # Replace spaces with %20 to create url correctly 
    city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key 
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Plettenberg Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=plettenberg%20bay
# Processing Record 2 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hilo
# City not found. Skipping...
# Processing Record 3 | Yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=yerbogachen
# Processing Record 4 | Asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=asyut
# Processing Record 5 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=norman%20wells
# Processing Record 6 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=punta%20arenas
# Processing Record 7 | Kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=kikwit
# Processing Record 8 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hamilton
# Processing Record 9 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=gamba
# Processing Record 10 | Itarema
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=itarema
# Processing Record 11 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=belmonte
# Processing Record 12 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=avarua
# Processing Record 13 | Porto Novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=porto%20novo
# Processing Record 14 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=thompson
# Processing Record 15 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=busselton
# Processing Record 16 | San Andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=san%20andres
# Processing Record 17 | Ouahigouya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=ouahigouya
# Processing Record 18 | Fayaoue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=fayaoue
# Processing Record 19 | Yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=yaan
# City not found. Skipping...
# Processing Record 20 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=jamestown
# Processing Record 21 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=ushuaia
# Processing Record 22 | Balkanabat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=balkanabat
# Processing Record 23 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=port%20alfred
# Processing Record 24 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=albany
# Processing Record 25 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=tilichiki
# Processing Record 26 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=nikolskoye
# Processing Record 27 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=arraial%20do%20cabo
# City not found. Skipping...
# Processing Record 28 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=rikitea
# Processing Record 29 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=leningradskiy
# Processing Record 30 | Skelleftea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=skelleftea
# Processing Record 31 | Muravlenko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=muravlenko
# Processing Record 32 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=east%20london
# Processing Record 33 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=dikson
# Processing Record 34 | Broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=broome
# Processing Record 35 | Belaya Gora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=belaya%20gora
# Processing Record 36 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hobyo
# Processing Record 37 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=mahebourg
# Processing Record 38 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=castro
# Processing Record 39 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=kapaa
# Processing Record 40 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hermanus
# Processing Record 41 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=mataura
# Processing Record 42 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=nuuk
# Processing Record 43 | Nhulunbuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=nhulunbuy
# Processing Record 44 | Amuntai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=amuntai
# City not found. Skipping...
# Processing Record 45 | Sept-Iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=sept-iles
# Processing Record 46 | Aswan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=aswan
# Processing Record 47 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=butaritari
# Processing Record 48 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=provideniya
# Processing Record 49 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=longyearbyen
# Processing Record 50 | Waingapu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=waingapu
# Processing Record 51 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=bambous%20virieux
# City not found. Skipping...
# Processing Record 52 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=havre-saint-pierre
# Processing Record 53 | Oga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=oga
# Processing Record 54 | Jalcocotan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=jalcocotan
# Processing Record 55 | Buzdyak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=buzdyak
# Processing Record 56 | Turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=turukhansk
# Processing Record 57 | Mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=mantua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 58 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=mount%20gambier
# Processing Record 59 | Touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=touros
# Processing Record 60 | Gobabis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=gobabis
# Processing Record 61 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=new%20norfolk
# Processing Record 62 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=cape%20town
# City not found. Skipping...
# Processing Record 63 | Eyl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=eyl
# Processing Record 64 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=dingle
# Processing Record 65 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=saint-philippe
# Processing Record 66 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=codrington
# City not found. Skipping...
# Processing Record 67 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=mar%20del%20plata
# Processing Record 68 | Banikoara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=banikoara
# Processing Record 69 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=atuona
# Processing Record 70 | Kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=kalabo
# Processing Record 71 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=bethel
# Processing Record 72 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=san%20patricio
# Processing Record 73 | Teguldet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=teguldet
# Processing Record 74 | Tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=tiksi
# City not found. Skipping...
# Processing Record 75 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=aklavik
# Processing Record 76 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=georgetown
# Processing Record 77 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hualmay
# Processing Record 78 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=ribeira%20grande
# City not found. Skipping...
# Processing Record 79 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=qaanaaq
# Processing Record 80 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=alofi
# Processing Record 81 | Waverly
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=waverly
# Processing Record 82 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=vaini
# Processing Record 83 | Salamanca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=salamanca
# Processing Record 84 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=carnarvon
# Processing Record 85 | Ayan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=ayan
# Processing Record 86 | Biala Podlaska
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=biala%20podlaska
# Processing Record 87 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=portland
# Processing Record 88 | Nyimba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=nyimba
# Processing Record 89 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=hobart
# Processing Record 90 | Isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=isangel
# Processing Record 91 | Eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=eureka
# Processing Record 92 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=cherskiy
# Processing Record 93 | Vero Beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=vero%20beach
# Processing Record 94 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=narsaq
# Processing Record 95 | Santa Clara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=santa%20clara
# Processing Record 96 | La Ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=la%20ronge
# Processing Record 97 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=ponta%20do%20sol
# Processing Record 98 | Guerrero Negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d7ec3e122241f5f141c01c8820d2036&q=guerrero%20negro

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a dictonary with the lists generated
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()

# %%
# Save data frame to CSV
weather_data.to_csv('weather_data.csv')

# Display data frame head 
weather_data.head()

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Cloudiness_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=10)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Wind_Speed_vs_Latitude.png")

# Show plot
plt.show()
